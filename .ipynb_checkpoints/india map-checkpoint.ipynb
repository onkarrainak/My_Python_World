# %%
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('india_state_geo.json')

# %%
print(gdf)
# Out:
#     ID_0  ISO NAME_0  ID_1                  NAME_1 NL_NAME_1  \
# 0    105  IND  India     1     Andaman and Nicobar      None
# 1    105  IND  India     2          Andhra Pradesh      None
# 2    105  IND  India     3       Arunachal Pradesh      None
# 3    105  IND  India     4                   Assam      None
# 4    105  IND  India     5                   Bihar      None
# 5    105  IND  India     6              Chandigarh      None
# 6    105  IND  India     7            Chhattisgarh      None
# 7    105  IND  India     8  Dadra and Nagar Haveli      None
# 8    105  IND  India     9           Daman and Diu      None
# 9    105  IND  India    10                   Delhi      None
# 10   105  IND  India    11                     Goa      None
# 11   105  IND  India    12                 Gujarat      None
# 12   105  IND  India    13                 Haryana      None
# 13   105  IND  India    14        Himachal Pradesh      None
# ...

# %%
gdf.plot()
# Out:
# <AxesSubplot:>
